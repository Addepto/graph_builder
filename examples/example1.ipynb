# %% [markdown]
# # Imports

# %%
import sys
import os
import pathlib

# %%
# for graph building
from entity_graph.graph_extractor.entities_graph_extractor import EntitiesGraphExtractor
# for partial results/debug:
import pandas as pd
from entity_graph.graph_extractor.processing.extraction_table import get_all_matching_tables
from entity_graph.graph_extractor.processing.models import TableFromHeaderExtracionConfig
from entity_graph.models.entity_graph.identifier import Identifier
from entity_graph.models.entity_graph.table import Table

# %% [markdown]
# # Data load

# %%
# main extractor
extractor = EntitiesGraphExtractor()

# %%
# helper reference to entities dict
entities = extractor.entities_graph_manager.entities

# %%
# source files dir
test_data_path = "../data/example1/"

# %%
# Test data peak
pd.read_csv(test_data_path+"accessories_flat.csv").head()
# Out:
#                     Accessory Name Compatible Machine ID  \
# 0      Milk Frothing Pitcher 350ml                 EX001
# 1           Water Filter AquaClean                 EX002
# 2  Coffee Bean Container Extension                 EX003
# 3        LatteCrema Milk Container                 EX001
# 4      Stainless Steel Tamper 58mm                 EX010
#
#                              Accessory Specification
# 0       Stainless steel jug for manual milk frothing
# 1  Reduces limescale; improves taste; fits AquaCl...
# 2               Extra 250g capacity for coffee beans
# 3  Removable container for milk frothing; dishwas...
# 4  Heavy-duty tamper for professional espresso ex...

# %%
# extracing from pdf directly, data filtering based on table header
config = {
    "extraction_type": "table_from_header",
    "filename": test_data_path + "coffee_machines.pdf",
    "header": ['Manufacturer', 'Coffee Machine Name', 'Machine ID', 'Production Year', 'Machine Type', 'Power (W)', 'Pressure (bar)', 'Water Tank Capacity (L)', 'Additional Features'],
}

# %%
# pdf extractor debug
get_all_matching_tables(TableFromHeaderExtracionConfig(**config), debug=True)
# Out:
# extract 1
# [[['Manufacturer',
#    'Coffee Machine Name',
#    'Machine ID',
#    'Production Year',
#    'Machine Type',
#    'Power (W)',
#    'Pressure (bar)',
#    'Water Tank Capacity (L)',
#    'Additional Features'],
#   ["De'Longhi",
#    'Magnifica S ECAM 22.110.B',
#    'EX001',
#    '2022',
#    'Automatic',
#    '1450',
#    '15',
#    '1.8',
#    'Steel grinder, cappuccino system'],
#   ['Philips',
#    'LatteGo EP3246/70',
#    'EX002',
#    '2023',
#    'Automatic',
#    '1500',
#    '15',
#    '1.8',
#    'LatteGo, touch screen'],
#   ['Jura',
#    'E8 Piano Black',
#    'EX003',
#    '2022',
#    'Automatic',
#    '1450',
#    '15',
#    '1.9',
#    'P.E.P., automatic cleaning'],
#   ['Saeco',
#    'Xelsis SM7685/00',
#    'EX004',
#    '2021',
#    'Automatic',
#    '1500',
#    '15',
#    '1.7',
#    '15 user profiles'],
#   ['Krups',
#    'Evidence EA893C',
#    'EX005',
#    '2022',
#    'Automatic',
#    '1450',
#    '15',
#    '2.3',
#    'Bluetooth, milk frothing'],
#   ['Melitta',
#    'Barista TS Smart F850-102',
#    'EX006',
#    '2023',
#    'Automatic',
#    '1450',
#    '15',
#    '1.8',
#    'Mobile app, double latte'],
#   ['Gaggia',
#    'Anima Prestige',
#    'EX007',
#    '2020',
#    'Automatic',
#    '1850',
#    '15',
#    '1.8',
#    'Milk container'],
#   ['Siemens',
#    'EQ.9 Plus s700',
#    'EX008',
#    '2023',
#    'Automatic',
#    '1500',
#    '19',
#    '2.3',
#    'Dual grinders, user profile'],
#   ['Miele',
#    'CM 6360 MilkPerfection',
#    'EX009',
#    '2022',
#    'Automatic',
#    '1500',
#    '15',
#    '1.8',
#    'AromaticSystem, WiFi'],
#   ['Breville',
#    'Barista Express',
#    'EX010',
#    '2021',
#    'Semi-automatic',
#    '1700',
#    '15',
#    '2.0',
#    'Conical grinder, steam wand'],
#   ["De'Longhi",
#    'Dinamica Plus ECAM 370.95.T',
#    'EX011',
#    '2022',
#    'Automatic',
#    '1450',
#    '15',
#    '1.8',
#    'LatteCrema, TFT display'],
#   ['Philips',
#    'Series 5000 EP5314/10',
#    'EX012',
#    '2020',
#    'Automatic',
#    '1850',
#    '15',
#    '1.8',
#    '5 coffee types, AquaClean filter'],
#   ['Jura',
#    'S8 Chrome',
#    'EX013',
#    '2023',
#    'Automatic',
#    '1450',
#    '15',
#    '1.9',
#    'Touch screen, P.E.P.'],
#   ['Krups',
#    'Intuition Preference EA8738',
#    'EX014',
#    '2022',
#    'Automatic',
#    '1450',
#    '15',
#    '2.3',
#    'Color display, profile saving'],
#   ['Saeco',
#    'PicoBaristo Deluxe SM5573/10',
#    'EX015',
#    '2021',
#    'Automatic',
#    '1850',
#    '15',
#    '1.7',
#    '12 coffee types, ceramic grinder'],
#   ['Melitta',
#    'Caffeo Solo & Milk E953-102',
#    'EX016',
#    '2020',
#    'Automatic',
#    '1400',
#    '15',
#    '1.2',
#    'Milk frothing nozzle'],
#   ['Gaggia',
#    'Classic Pro',
#    'EX017',
#    '2023',
#    'Semi-automatic',
#    '1450',
#    '15',
#    '2.1',
#    'Brass group, steam wand'],
#   ['Siemens',
#    'EQ.6 Plus S700',
#    'EX018',
#    '2021',
#    'Automatic',
#    '1500',
#    '19',
#    '1.7',
#    'Latte Macchiato OneTouch'],
#   ['Miele',
#    'CM 5510 Silence',
#    'EX019',
#    '2022',
#    'Automatic',
#    '1500',
#    '15',
#    '1.8',
#    'Low-noise operation, Aroma System'],
#   ['Breville',
#    'Oracle Touch',
#    'EX020',
#    '2023',
#    'Semi-automatic',
#    '2400',
#    '15',
#    '2.5',
#    'Automatic milk frothing'],
#   ["De'Longhi",
#    'PrimaDonna Soul ECAM 610.74',
#    'EX021',
#    '2023',
#    'Automatic',
#    '1450',
#    '19',
#    '2.2',
#    'Bean Adapt, LatteCrema'],
#   ['Philips',
#    '2200 Series EP2224/40',
#    'EX022',
#    '2021',
#    'Automatic',
#    '1500',
#    '15',
#    '1.8',
#    'Touch panel, AquaClean'],
#   ['Jura',
#    'Z6 Diamond Black',
#    'EX023',
#    '2023',
#    'Automatic',
#    '1450',
#    '15',
#    '2.4',
#    'Intelligent coffee sensor'],
#   ['Krups',
#    'Arabica EA8110',
#    'EX024',
#    '2020',
#    'Automatic',
#    '1450',
#    '15',
#    '1.7',
#    'Compact size'],
#   ['Saeco',
#    'GranAroma SM6585/00',
#    'EX025',
#    '2023',
#    'Automatic',
#    '1500',
#    '15',
#    '1.8',
#    '24 coffee recipes'],
#   ['Melitta',
#    'Purista F230-102',
#    'EX026',
#    '2022',
#    'Automatic',
#    '1450',
#    '15',
#    '1.2',
#    'IntenseAroma function'],
#   ['Gaggia',
#    'Velasca Prestige',
#    'EX027',
#    '2021',
#    'Automatic',
#    '1850',
#    '15',
#    '1.5',
#    'Milk container'],
#   ['Siemens',
#    'EQ.500 Integral TQ507R02',
#    'EX028',
#    '2022',
#    'Automatic',
#    '1500',
#    '19',
#    '1.7',
#    'Integrated milk container'],
#   ['Miele',
#    'CM 7750 CoffeeSelect',
#    'EX029',
#    '2023',
#    'Automatic',
#    '1500',
#    '15',
#    '2.2',
#    '3 bean containers'],
#   ['Breville',
#    'Bambino Plus',
#    'EX030',
#    '2021',
#    'Semi-automatic',
#    '1600',
#    '15',
#    '1.4',
#    'Fast heat-up, steam wand']]]

# %%
# Load table to graph
extractor.load_table_from_file(
    config,
    "coffee_machines.pdf", 
    "Machines", 
    "instances",
)
# Out:
# Extraction! From {'extraction_type': 'table_from_header', 'filename': '../data/example1/coffee_machines.pdf', 'header': ['Manufacturer', 'Coffee Machine Name', 'Machine ID', 'Production Year', 'Machine Type', 'Power (W)', 'Pressure (bar)', 'Water Tank Capacity (L)', 'Additional Features']}
# doing config: data_type=<OutputDataType.DATAFRAME: 'dataframe'> filename='../data/example1/coffee_machines.pdf' extraction_type=<ExtractionType.TABLE_FROM_HEADER: 'table_from_header'> header=['Manufacturer', 'Coffee Machine Name', 'Machine ID', 'Production Year', 'Machine Type', 'Power (W)', 'Pressure (bar)', 'Water Tank Capacity (L)', 'Additional Features'] pages=None columns_to_split=None prefixes=None
# extract 1
# 2025-08-26 11:06:51.958 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 1 objects created 1 unique keys

# %%
# Load table to graph
extractor.load_table_from_file(
    test_data_path+"accessories_flat.csv",
    "accessories.csv", 
    "Accessories", 
    "instances",
)
# Out:
# 2025-08-26 11:06:51.982 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 33 objects created 33 unique keys

# %% [markdown]
# # Graph building

# %%
# define graph building steps
steps = {
    "identifiers": [
        # helper identifier objects, needs name, table name and columns, optionally reads all id values
        ("MachineID", "Machines", ["Machine ID"], False),
    ],
    "identifiers_links": [
        # adds existing identifier object to a new table, needs name, table name and columns, optionally reads all id values
        ("MachineID", "Accessories", ["Compatible Machine ID"], False),
    ],
    "instances_creation": [
        # defines sources of objects to put in the graph, needs identifier name and table, optionally creates hierarchy or uses columns different than the identifier
        ("MachineID", "Machines", False, None),
    ],
    "enrichments": [
        # enriches objects with data from other sources, needs new data source table name, object attribute name, new source attribute and attribute to use as id of new nodes
        ("Accessories", "Machine ID", "Compatible Machine ID", ["Accessory Name"]),
    ],
}

# %%
extractor.extract_entities_graph(steps)
# Out:
# 2025-08-26 11:06:52.025 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 50 objects created 50 unique keys
# 2025-08-26 11:06:52.030 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 80 objects created 80 unique keys
# 2025-08-26 11:06:52.033 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 80 objects created 80 unique keys
# 2025-08-26 11:06:52.036 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 95 objects created 95 unique keys
# 2025-08-26 11:06:52.039 | DEBUG    | entity_graph.graph_manager:refresh_name_map:43 - Creating collection name map, from 95 objects created 95 unique keys
# Name map has 95 entries in collection 'default'
# Created 0 parent-child relationships in collection 'default'

# %% [markdown]
# # Graph checks

# %%
# check identifiers
identifiers = [
    v for k,v in entities.items()     if isinstance(v, Identifier)
]
identifiers

# %%
identifiers[0].data
# Out:
# {'values': {'EX001',
#   'EX002',
#   'EX003',
#   'EX004',
#   'EX005',
#   'EX006',
#   'EX007',
#   'EX008',
#   'EX009',
#   'EX010',
#   'EX011',
#   'EX012',
#   'EX013',
#   'EX014',
#   'EX015',
#   'EX016',
#   'EX017',
#   'EX018',
#   'EX019',
#   'EX020',
#   'EX021',
#   'EX022',
#   'EX023',
#   'EX024',
#   'EX025',
#   'EX026',
#   'EX027',
#   'EX028',
#   'EX029',
#   'EX030'}}

# %%
# export objects
graph_export = extractor.export_graph()
# nodes ids
graph_export[0]
# Out:
# ['EX001',
#  'EX002',
#  'EX003',
#  'EX004',
#  'EX005',
#  'EX006',
#  'EX007',
#  'EX008',
#  'EX009',
#  'EX010',
#  'EX011',
#  'EX012',
#  'EX013',
#  'EX014',
#  'EX015',
#  'EX016',
#  'EX017',
#  'EX018',
#  'EX019',
#  'EX020',
#  'EX021',
#  'EX022',
#  'EX023',
#  'EX024',
#  'EX025',
#  'EX026',
#  'EX027',
#  'EX028',
#  'EX029',
#  'EX030',
#  'EX010|Stainless Steel Tamper 58mm',
#  'EX010|Professional Knock Box',
#  'EX010|Barista Digital Scale',
#  'EX004|Ceramic Burr Grinder Replacement',
#  'EX008|WiFi Module Upgrade',
#  'EX005|Coffee Grounds Container Large',
#  'EX002|Water Filter AquaClean',
#  'EX002|Travel Mug Stainless Steel 350ml',
#  'EX001|Milk Frothing Pitcher 350ml',
#  'EX001|LatteCrema Milk Container',
#  'EX001|Descaling Kit Universal',
#  'EX001|Cappuccino Art Stencil Set',
#  'EX003|Coffee Bean Container Extension',
#  'EX003|Cold Brew Adapter Kit',
#  'EX007|Dual Cup Espresso Glass Set']

# %%
# edges
graph_export[1]
# Out:
# [('EX001', 'EX001|Milk Frothing Pitcher 350ml'),
#  ('EX001', 'EX001|LatteCrema Milk Container'),
#  ('EX001', 'EX001|Descaling Kit Universal'),
#  ('EX001', 'EX001|Cappuccino Art Stencil Set'),
#  ('EX002', 'EX002|Water Filter AquaClean'),
#  ('EX002', 'EX002|Travel Mug Stainless Steel 350ml'),
#  ('EX003', 'EX003|Coffee Bean Container Extension'),
#  ('EX003', 'EX003|Cold Brew Adapter Kit'),
#  ('EX004', 'EX004|Ceramic Burr Grinder Replacement'),
#  ('EX005', 'EX005|Coffee Grounds Container Large'),
#  ('EX007', 'EX007|Dual Cup Espresso Glass Set'),
#  ('EX008', 'EX008|WiFi Module Upgrade'),
#  ('EX010', 'EX010|Stainless Steel Tamper 58mm'),
#  ('EX010', 'EX010|Professional Knock Box'),
#  ('EX010', 'EX010|Barista Digital Scale')]

# %%
# nodes data
graph_export[2]
# Out:
# {'EX001': {'Manufacturer': "De'Longhi",
#   'Coffee Machine Name': 'Magnifica S ECAM 22.110.B',
#   'Machine ID': 'EX001',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'Steel grinder, cappuccino system',
#   'collection': 'default'},
#  'EX002': {'Manufacturer': 'Philips',
#   'Coffee Machine Name': 'LatteGo EP3246/70',
#   'Machine ID': 'EX002',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'LatteGo, touch screen',
#   'collection': 'default'},
#  'EX003': {'Manufacturer': 'Jura',
#   'Coffee Machine Name': 'E8 Piano Black',
#   'Machine ID': 'EX003',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.9',
#   'Additional Features': 'P.E.P., automatic cleaning',
#   'collection': 'default'},
#  'EX004': {'Manufacturer': 'Saeco',
#   'Coffee Machine Name': 'Xelsis SM7685/00',
#   'Machine ID': 'EX004',
#   'Production Year': '2021',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.7',
#   'Additional Features': '15 user profiles',
#   'collection': 'default'},
#  'EX005': {'Manufacturer': 'Krups',
#   'Coffee Machine Name': 'Evidence EA893C',
#   'Machine ID': 'EX005',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.3',
#   'Additional Features': 'Bluetooth, milk frothing',
#   'collection': 'default'},
#  'EX006': {'Manufacturer': 'Melitta',
#   'Coffee Machine Name': 'Barista TS Smart F850-102',
#   'Machine ID': 'EX006',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'Mobile app, double latte',
#   'collection': 'default'},
#  'EX007': {'Manufacturer': 'Gaggia',
#   'Coffee Machine Name': 'Anima Prestige',
#   'Machine ID': 'EX007',
#   'Production Year': '2020',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1850',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'Milk container',
#   'collection': 'default'},
#  'EX008': {'Manufacturer': 'Siemens',
#   'Coffee Machine Name': 'EQ.9 Plus s700',
#   'Machine ID': 'EX008',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '19',
#   'Water Tank Capacity (L)': '2.3',
#   'Additional Features': 'Dual grinders, user profile',
#   'collection': 'default'},
#  'EX009': {'Manufacturer': 'Miele',
#   'Coffee Machine Name': 'CM 6360 MilkPerfection',
#   'Machine ID': 'EX009',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'AromaticSystem, WiFi',
#   'collection': 'default'},
#  'EX010': {'Manufacturer': 'Breville',
#   'Coffee Machine Name': 'Barista Express',
#   'Machine ID': 'EX010',
#   'Production Year': '2021',
#   'Machine Type': 'Semi-automatic',
#   'Power (W)': '1700',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.0',
#   'Additional Features': 'Conical grinder, steam wand',
#   'collection': 'default'},
#  'EX011': {'Manufacturer': "De'Longhi",
#   'Coffee Machine Name': 'Dinamica Plus ECAM 370.95.T',
#   'Machine ID': 'EX011',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'LatteCrema, TFT display',
#   'collection': 'default'},
#  'EX012': {'Manufacturer': 'Philips',
#   'Coffee Machine Name': 'Series 5000 EP5314/10',
#   'Machine ID': 'EX012',
#   'Production Year': '2020',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1850',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': '5 coffee types, AquaClean filter',
#   'collection': 'default'},
#  'EX013': {'Manufacturer': 'Jura',
#   'Coffee Machine Name': 'S8 Chrome',
#   'Machine ID': 'EX013',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.9',
#   'Additional Features': 'Touch screen, P.E.P.',
#   'collection': 'default'},
#  'EX014': {'Manufacturer': 'Krups',
#   'Coffee Machine Name': 'Intuition Preference EA8738',
#   'Machine ID': 'EX014',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.3',
#   'Additional Features': 'Color display, profile saving',
#   'collection': 'default'},
#  'EX015': {'Manufacturer': 'Saeco',
#   'Coffee Machine Name': 'PicoBaristo Deluxe SM5573/10',
#   'Machine ID': 'EX015',
#   'Production Year': '2021',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1850',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.7',
#   'Additional Features': '12 coffee types, ceramic grinder',
#   'collection': 'default'},
#  'EX016': {'Manufacturer': 'Melitta',
#   'Coffee Machine Name': 'Caffeo Solo & Milk E953-102',
#   'Machine ID': 'EX016',
#   'Production Year': '2020',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1400',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.2',
#   'Additional Features': 'Milk frothing nozzle',
#   'collection': 'default'},
#  'EX017': {'Manufacturer': 'Gaggia',
#   'Coffee Machine Name': 'Classic Pro',
#   'Machine ID': 'EX017',
#   'Production Year': '2023',
#   'Machine Type': 'Semi-automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.1',
#   'Additional Features': 'Brass group, steam wand',
#   'collection': 'default'},
#  'EX018': {'Manufacturer': 'Siemens',
#   'Coffee Machine Name': 'EQ.6 Plus S700',
#   'Machine ID': 'EX018',
#   'Production Year': '2021',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '19',
#   'Water Tank Capacity (L)': '1.7',
#   'Additional Features': 'Latte Macchiato OneTouch',
#   'collection': 'default'},
#  'EX019': {'Manufacturer': 'Miele',
#   'Coffee Machine Name': 'CM 5510 Silence',
#   'Machine ID': 'EX019',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'Low-noise operation, Aroma System',
#   'collection': 'default'},
#  'EX020': {'Manufacturer': 'Breville',
#   'Coffee Machine Name': 'Oracle Touch',
#   'Machine ID': 'EX020',
#   'Production Year': '2023',
#   'Machine Type': 'Semi-automatic',
#   'Power (W)': '2400',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.5',
#   'Additional Features': 'Automatic milk frothing',
#   'collection': 'default'},
#  'EX021': {'Manufacturer': "De'Longhi",
#   'Coffee Machine Name': 'PrimaDonna Soul ECAM 610.74',
#   'Machine ID': 'EX021',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '19',
#   'Water Tank Capacity (L)': '2.2',
#   'Additional Features': 'Bean Adapt, LatteCrema',
#   'collection': 'default'},
#  'EX022': {'Manufacturer': 'Philips',
#   'Coffee Machine Name': '2200 Series EP2224/40',
#   'Machine ID': 'EX022',
#   'Production Year': '2021',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': 'Touch panel, AquaClean',
#   'collection': 'default'},
#  'EX023': {'Manufacturer': 'Jura',
#   'Coffee Machine Name': 'Z6 Diamond Black',
#   'Machine ID': 'EX023',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.4',
#   'Additional Features': 'Intelligent coffee sensor',
#   'collection': 'default'},
#  'EX024': {'Manufacturer': 'Krups',
#   'Coffee Machine Name': 'Arabica EA8110',
#   'Machine ID': 'EX024',
#   'Production Year': '2020',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.7',
#   'Additional Features': 'Compact size',
#   'collection': 'default'},
#  'EX025': {'Manufacturer': 'Saeco',
#   'Coffee Machine Name': 'GranAroma SM6585/00',
#   'Machine ID': 'EX025',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.8',
#   'Additional Features': '24 coffee recipes',
#   'collection': 'default'},
#  'EX026': {'Manufacturer': 'Melitta',
#   'Coffee Machine Name': 'Purista F230-102',
#   'Machine ID': 'EX026',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1450',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.2',
#   'Additional Features': 'IntenseAroma function',
#   'collection': 'default'},
#  'EX027': {'Manufacturer': 'Gaggia',
#   'Coffee Machine Name': 'Velasca Prestige',
#   'Machine ID': 'EX027',
#   'Production Year': '2021',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1850',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.5',
#   'Additional Features': 'Milk container',
#   'collection': 'default'},
#  'EX028': {'Manufacturer': 'Siemens',
#   'Coffee Machine Name': 'EQ.500 Integral TQ507R02',
#   'Machine ID': 'EX028',
#   'Production Year': '2022',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '19',
#   'Water Tank Capacity (L)': '1.7',
#   'Additional Features': 'Integrated milk container',
#   'collection': 'default'},
#  'EX029': {'Manufacturer': 'Miele',
#   'Coffee Machine Name': 'CM 7750 CoffeeSelect',
#   'Machine ID': 'EX029',
#   'Production Year': '2023',
#   'Machine Type': 'Automatic',
#   'Power (W)': '1500',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '2.2',
#   'Additional Features': '3 bean containers',
#   'collection': 'default'},
#  'EX030': {'Manufacturer': 'Breville',
#   'Coffee Machine Name': 'Bambino Plus',
#   'Machine ID': 'EX030',
#   'Production Year': '2021',
#   'Machine Type': 'Semi-automatic',
#   'Power (W)': '1600',
#   'Pressure (bar)': '15',
#   'Water Tank Capacity (L)': '1.4',
#   'Additional Features': 'Fast heat-up, steam wand',
#   'collection': 'default'},
#  'EX010|Stainless Steel Tamper 58mm': {'Accessory Name': 'Stainless Steel Tamper 58mm',
#   'Compatible Machine ID': 'EX010',
#   'Accessory Specification': 'Heavy-duty tamper for professional espresso extraction',
#   'collection': 'default'},
#  'EX010|Professional Knock Box': {'Accessory Name': 'Professional Knock Box',
#   'Compatible Machine ID': 'EX010',
#   'Accessory Specification': 'Waste container for used coffee pucks',
#   'collection': 'default'},
#  'EX010|Barista Digital Scale': {'Accessory Name': 'Barista Digital Scale',
#   'Compatible Machine ID': 'EX010',
#   'Accessory Specification': 'Precision scale with timer for espresso brewing',
#   'collection': 'default'},
#  'EX004|Ceramic Burr Grinder Replacement': {'Accessory Name': 'Ceramic Burr Grinder Replacement',
#   'Compatible Machine ID': 'EX004',
#   'Accessory Specification': 'OEM replacement ceramic grinder burr set',
#   'collection': 'default'},
#  'EX008|WiFi Module Upgrade': {'Accessory Name': 'WiFi Module Upgrade',
#   'Compatible Machine ID': 'EX008',
#   'Accessory Specification': 'Adds wireless connectivity for app control',
#   'collection': 'default'},
#  'EX005|Coffee Grounds Container Large': {'Accessory Name': 'Coffee Grounds Container Large',
#   'Compatible Machine ID': 'EX005',
#   'Accessory Specification': 'Increased capacity for used coffee grounds',
#   'collection': 'default'},
#  'EX002|Water Filter AquaClean': {'Accessory Name': 'Water Filter AquaClean',
#   'Compatible Machine ID': 'EX002',
#   'Accessory Specification': 'Reduces limescale; improves taste; fits AquaClean slot',
#   'collection': 'default'},
#  'EX002|Travel Mug Stainless Steel 350ml': {'Accessory Name': 'Travel Mug Stainless Steel 350ml',
#   'Compatible Machine ID': 'EX002',
#   'Accessory Specification': 'Fits machine outlet directly for on-the-go coffee',
#   'collection': 'default'},
#  'EX001|Milk Frothing Pitcher 350ml': {'Accessory Name': 'Milk Frothing Pitcher 350ml',
#   'Compatible Machine ID': 'EX001',
#   'Accessory Specification': 'Stainless steel jug for manual milk frothing',
#   'collection': 'default'},
#  'EX001|LatteCrema Milk Container': {'Accessory Name': 'LatteCrema Milk Container',
#   'Compatible Machine ID': 'EX001',
#   'Accessory Specification': 'Removable container for milk frothing; dishwasher safe',
#   'collection': 'default'},
#  'EX001|Descaling Kit Universal': {'Accessory Name': 'Descaling Kit Universal',
#   'Compatible Machine ID': 'EX001',
#   'Accessory Specification': 'Liquid solution for removing limescale from coffee machines',
#   'collection': 'default'},
#  'EX001|Cappuccino Art Stencil Set': {'Accessory Name': 'Cappuccino Art Stencil Set',
#   'Compatible Machine ID': 'EX001',
#   'Accessory Specification': 'Stainless steel stencils for decorating milk foam',
#   'collection': 'default'},
#  'EX003|Coffee Bean Container Extension': {'Accessory Name': 'Coffee Bean Container Extension',
#   'Compatible Machine ID': 'EX003',
#   'Accessory Specification': 'Extra 250g capacity for coffee beans',
#   'collection': 'default'},
#  'EX003|Cold Brew Adapter Kit': {'Accessory Name': 'Cold Brew Adapter Kit',
#   'Compatible Machine ID': 'EX003',
#   'Accessory Specification': 'Allows brewing cold coffee directly from machine',
#   'collection': 'default'},
#  'EX007|Dual Cup Espresso Glass Set': {'Accessory Name': 'Dual Cup Espresso Glass Set',
#   'Compatible Machine ID': 'EX007',
#   'Accessory Specification': 'Double-wall borosilicate glass; 60ml capacity',
#   'collection': 'default'}}

# %%
# see node data
graph_export[2]['EX001|Milk Frothing Pitcher 350ml']
# Out:
# {'Accessory Name': 'Milk Frothing Pitcher 350ml',
#  'Compatible Machine ID': 'EX001',
#  'Accessory Specification': 'Stainless steel jug for manual milk frothing',
#  'collection': 'default'}

# %%
# see relations in the manager class
extractor.entities_graph_manager.find_entity("EX001").relations
# Out:
# [('from_artifact', '184b1078-0e41-4df9-a6f8-e85ce23debd8', None),
#  ('parent_of',
#   '0e1ba85b-450d-439a-8a38-a113f1992314',
#   {'confidence': 'medium'}),
#  ('parent_of',
#   'b327799f-a772-4fd8-9ac8-3244f13ece81',
#   {'confidence': 'medium'}),
#  ('parent_of',
#   'c9cf8d4d-fcb2-402d-a005-a3a4246ba064',
#   {'confidence': 'medium'}),
#  ('parent_of',
#   '9d2dd902-c4ad-4ea6-81cc-a10b39aea4b7',
#   {'confidence': 'medium'})]

# %%
extractor.entities_graph_manager.find_entity("Machines_0").relations
# Out:
# [('in_table', 'e53fa410-b64c-4773-a666-d4ce2d8d4b95', None),
#  ('from_artifact', '414611d6-ad9f-45e3-ab0f-425c0409c1bd', None)]

# %%
extractor.entities_graph_manager.get_named_entity_relations("EX001", "from_artifact")

# %% [markdown]
# # Tests

# %%
assert "Machines_0" in [
    e.name for e in
    extractor.entities_graph_manager.get_named_entity_relations("EX001", "from_artifact")
]

# %%
assert "Machines" in [
    e.name for e in
    extractor.entities_graph_manager.get_named_entity_relations("Machines_0", "in_table")
]
